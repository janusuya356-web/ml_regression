# %%
import pandas as pd

# %%
dataset=pd.read_csv("RND.csv")
print(dataset)
# Out:
#    R&D      Spend  Administration  Marketing Spend       State     Profit
# 0    0  165349.20       136897.80        471784.10     Newyork  192261.83
# 1    1  162597.70       151377.59        443898.53  California  191792.06
# 2    2  153441.51       101145.55        407934.54     Florida  191050.39
# 3    3  144372.41       118671.85        383199.62     Newyork  182901.99
# 4    4  142107.34        91391.77        366168.42     Florida  166187.94
# 5    5  131876.90        99814.71        362861.36     newyork  156991.12
# 6    6  134615.46       147198.87        127716.82  California  156122.51
# 7    7  130298.13       145530.06        323876.68     Florida  155752.60
# 8    8  120542.52       148718.95        311613.29     Newyork  152211.77
# 9    9  123334.88       108679.17        304981.62  California  149759.96

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#    R&D      Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0    0  165349.20       136897.80        471784.10  192261.83          False
# 1    1  162597.70       151377.59        443898.53  191792.06          False
# 2    2  153441.51       101145.55        407934.54  191050.39           True
# 3    3  144372.41       118671.85        383199.62  182901.99          False
# 4    4  142107.34        91391.77        366168.42  166187.94           True
# 5    5  131876.90        99814.71        362861.36  156991.12          False
# 6    6  134615.46       147198.87        127716.82  156122.51          False
# 7    7  130298.13       145530.06        323876.68  155752.60           True
# 8    8  120542.52       148718.95        311613.29  152211.77          False
# 9    9  123334.88       108679.17        304981.62  149759.96          False
#
#    State_Newyork  State_newyork
# 0           True          False
# 1          False          False
# 2          False          False
# 3           True          False
# 4          False          False
# 5          False           True
# 6          False          False
# 7          False          False
# 8           True          False
# 9          False          False

# %%
independent=dataset[['R&D', 'Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_Newyork', 'State_newyork']]
print(independent)
dependent=dataset[["Profit"]] 
print(dependent)
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30,random_state=0)
# Out:
#    R&D      Spend  Administration  Marketing Spend  State_Florida  \
# 0    0  165349.20       136897.80        471784.10          False
# 1    1  162597.70       151377.59        443898.53          False
# 2    2  153441.51       101145.55        407934.54           True
# 3    3  144372.41       118671.85        383199.62          False
# 4    4  142107.34        91391.77        366168.42           True
# 5    5  131876.90        99814.71        362861.36          False
# 6    6  134615.46       147198.87        127716.82          False
# 7    7  130298.13       145530.06        323876.68           True
# 8    8  120542.52       148718.95        311613.29          False
# 9    9  123334.88       108679.17        304981.62          False
#
#    State_Newyork  State_newyork
# 0           True          False
# 1          False          False
# 2          False          False
# 3           True          False
# 4          False          False
# 5          False           True
# 6          False          False
# 7          False          False
# 8           True          False
# 9          False          False
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94
# 5  156991.12
# 6  156122.51
# 7  155752.60
# 8  152211.77
# 9  149759.96

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_train
# Out:
# array([[ 1.51524392, -1.21343246, -1.10660839, -0.38635314, -0.40824829,
#         -0.63245553, -0.40824829],
#        [-1.13643294,  1.36982176,  1.13706477,  0.93910233, -0.40824829,
#         -0.63245553, -0.40824829],
#        [ 0.5208651 , -0.47123906,  0.91748564, -2.07769942, -0.40824829,
#         -0.63245553, -0.40824829],
#        [ 0.8523247 , -0.75529306,  0.82979471, -0.20606868,  2.44948974,
#         -0.63245553, -0.40824829],
#        [-0.47351372,  0.17070877, -0.5815232 ,  0.35995251, -0.40824829,
#          1.58113883, -0.40824829],
#        [-1.46789254,  1.55085368,  0.37619549,  1.20516843, -0.40824829,
#          1.58113883, -0.40824829],
#        [ 0.18940549, -0.65141962, -1.57240902,  0.16589797, -0.40824829,
#         -0.63245553,  2.44948974]])

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)
y_train
# Out:
# array([[-1.12980455],
#        [ 1.29195499],
#        [-0.76321411],
#        [-0.78452718],
#        [ 0.77973666],
#        [ 1.31902168],
#        [-0.71316749]])

# %%
preinput=sc.transform([[1300,1200,4000,0,1,45,678]])
preinput
# Out:
# C:\Users\Techs\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 429.42959612,   -9.24916307,   -6.60718299,   -3.29629086,
#            2.44948974,   98.97929076, 1937.13813825]])

# %%
import pickle
loaded_model=pickle.load(open("finalized_model_svm.sav",'rb'))
result=loaded_model.predict(preinput)
print(result)
# Out:
# [-0.08489425]

# %%
loaded_model=pickle.load(open("finalized_model_svm.sav",'rb'))
result=loaded_model.predict(preinput)
print(result)
# Out:
# [-0.08489425]

# %%
preoutput=scy.inverse_transform([result])
preoutput
# Out:
# array([[167895.44110853]])
