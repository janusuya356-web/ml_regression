# %%
import pandas as pd
dataset=pd.read_csv("RND.csv")
print(dataset)
# Out:
#    R&D      Spend  Administration  Marketing Spend       State     Profit
# 0    0  165349.20       136897.80        471784.10     Newyork  192261.83
# 1    1  162597.70       151377.59        443898.53  California  191792.06
# 2    2  153441.51       101145.55        407934.54     Florida  191050.39
# 3    3  144372.41       118671.85        383199.62     Newyork  182901.99
# 4    4  142107.34        91391.77        366168.42     Florida  166187.94
# 5    5  131876.90        99814.71        362861.36     newyork  156991.12
# 6    6  134615.46       147198.87        127716.82  California  156122.51
# 7    7  130298.13       145530.06        323876.68     Florida  155752.60
# 8    8  120542.52       148718.95        311613.29     Newyork  152211.77
# 9    9  123334.88       108679.17        304981.62  California  149759.96

# %%
dataset.columns
# Out:
# Index(['R&D', 'Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
dataset=pd.get_dummies(dataset)
print(dataset)
# Out:
#    R&D      Spend  Administration  Marketing Spend     Profit  \
# 0    0  165349.20       136897.80        471784.10  192261.83
# 1    1  162597.70       151377.59        443898.53  191792.06
# 2    2  153441.51       101145.55        407934.54  191050.39
# 3    3  144372.41       118671.85        383199.62  182901.99
# 4    4  142107.34        91391.77        366168.42  166187.94
# 5    5  131876.90        99814.71        362861.36  156991.12
# 6    6  134615.46       147198.87        127716.82  156122.51
# 7    7  130298.13       145530.06        323876.68  155752.60
# 8    8  120542.52       148718.95        311613.29  152211.77
# 9    9  123334.88       108679.17        304981.62  149759.96
#
#    State_California  State_Florida  State_Newyork  State_newyork
# 0             False          False           True          False
# 1              True          False          False          False
# 2             False           True          False          False
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#    R&D      Spend  Administration  Marketing Spend     Profit  \
# 0    0  165349.20       136897.80        471784.10  192261.83
# 1    1  162597.70       151377.59        443898.53  191792.06
# 2    2  153441.51       101145.55        407934.54  191050.39
# 3    3  144372.41       118671.85        383199.62  182901.99
# 4    4  142107.34        91391.77        366168.42  166187.94
# 5    5  131876.90        99814.71        362861.36  156991.12
# 6    6  134615.46       147198.87        127716.82  156122.51
# 7    7  130298.13       145530.06        323876.68  155752.60
# 8    8  120542.52       148718.95        311613.29  152211.77
# 9    9  123334.88       108679.17        304981.62  149759.96
#
#    State_California  State_Florida  State_Newyork  State_newyork
# 0             False          False           True          False
# 1              True          False          False          False
# 2             False           True          False          False
# ...

# %%
independent=dataset[['R&D', 'Spend', 'Administration', 'Marketing Spend', 'State_California', 'State_Florida', 'State_Newyork', 'State_newyork']]
print(independent)
# Out:
#    R&D      Spend  Administration  Marketing Spend  State_California  \
# 0    0  165349.20       136897.80        471784.10             False
# 1    1  162597.70       151377.59        443898.53              True
# 2    2  153441.51       101145.55        407934.54             False
# 3    3  144372.41       118671.85        383199.62             False
# 4    4  142107.34        91391.77        366168.42             False
# 5    5  131876.90        99814.71        362861.36             False
# 6    6  134615.46       147198.87        127716.82              True
# 7    7  130298.13       145530.06        323876.68             False
# 8    8  120542.52       148718.95        311613.29             False
# 9    9  123334.88       108679.17        304981.62              True
#
#    State_Florida  State_Newyork  State_newyork
# 0          False           True          False
# 1          False          False          False
# 2           True          False          False
# ...

# %%
dataset.columns
# Out:
# Index(['R&D', 'Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_California', 'State_Florida', 'State_Newyork', 'State_newyork'],
#       dtype='object')

# %%
dependent=dataset[["Profit"]] 
print(dependent)
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94
# 5  156991.12
# 6  156122.51
# 7  155752.60
# 8  152211.77
# 9  149759.96

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

regressor.fit(x_train,y_train)
 
LinearRegression()
weight=regressor.coef_
print(weight)
bais=regressor.intercept_ 
print(bais)
# Out:
# [[-1.02643569e+04 -1.69523876e+00  3.06207630e-01  9.64786593e-02
#    1.03601681e+04 -5.47852811e+03  6.97349045e+03 -1.18551305e+04]]
# [378158.46400467]

# %%
y_pred=regressor.predict(x_test) 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
print(r_score)
# Out:
# -0.8833175369013833

# %%
import pickle
filename="finalized_model_mul_linear.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[12,43,56,689,7,898,368,208]])
print(result)
# Out:
# [[-4491822.80971687]]
# C:\Users\Techs\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
